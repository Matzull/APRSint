# %%
import aprslib as aprs
import gzip as gz
import os

# %% [markdown]
# # Load data

# %%
DATA_PATH = "../../database"

# %%
aprs.parse("HS6KLJ-3>AESPG4,TCPIP*,qAC,T2CS::HS6KLJ-3 :UNIT.Pkt,Pkt,Pkt,dBm,V")
# Out:
# {'raw': 'HS6KLJ-3>AESPG4,TCPIP*,qAC,T2CS::HS6KLJ-3 :UNIT.Pkt,Pkt,Pkt,dBm,V',
#  'from': 'HS6KLJ-3',
#  'to': 'AESPG4',
#  'path': ['TCPIP*', 'qAC', 'T2CS'],
#  'via': 'T2CS',
#  'addresse': 'HS6KLJ-3',
#  'format': 'telemetry-message',
#  'tUNIT': ['Pkt', 'Pkt', 'Pkt', 'dBm', 'V', '', '', '', '', '', '', '', '']}

# %%
packets = []
for file in os.listdir(DATA_PATH):
    if file.endswith(".gz"):
        with gz.open(os.path.join(DATA_PATH, file), 'rb') as f:
            for line in f.readlines():
                try:
                    packets.append(aprs.parse(line[:-1]))
                except Exception as e:
                    print('Error parsing line: ' + line.decode('utf-8') + " " + str(e))
# Out:
# Error parsing line: TF1APA>APMI06,WIDE2-1,qAR,TF1MT-1:T#199,187,036,000,000,060,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-EA8CZR>RXTLM-1,TCPIP,qAR,EA8CZR:T#688,0.40,0.00,2,1,0.0,10000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: OE8NDR-11>APMI06,TCPIP*,qAS,OE8NDR:@Greetings from Fritz-OE8NDR
#  invalid format
# Error parsing line: EL-DL7UBB>RXTLM-1,TCPIP,qAR,DL7UBB:T#072,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: TA6B-11>AESPG4,TCPIP*,qAC,T2CZECH:T#018,23,2,5,74,14.56,00000000,@ 19 41 1 13 11 2023
#  Format is not supported: 'T' telemetry report
# Error parsing line: ER-IQ2XN>RXTLM-1,TCPIP,qAR,IQ2XN:T#204,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-RK0W>RXTLM-1,TCPIP,qAR,RK0W:T#455,0.00,0.01,0,2,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: SP9UVG-13>APMI06,TCPIP*,qAC,T2POLAND:T#042,163,048,021,091,088,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: ER-HL5QQ>RXTLM-1,TCPIP,qAR,HL5QQ:T#756,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-RR6HJ>RXTLM-1,TCPIP,qAR,RR6HJ:T#393,0.00,0.01,0,1,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: VK2RWN-B>APJI43,TCPIP*,qAC,VK2RWN-GS:<IGATE,MSG_CNT=0,LOC_CNT=0
#  Format is not supported: '<' station capabilities
# Error parsing line: OZ1BZJ-1>APRX29,TCPIP*,qAC,T2FINLAND:T#332,15.9,2.7,71.0,21.0,11.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: SR5ZBL>APRX29,TCPIP*,qAC,T2POLC:T#119,38.3,1.2,183.0,8.0,4.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: SR5ZBL-2>APRX29,TCPIP*,qAS,SR5ZBL:T#119,12.3,10.2,55.0,6.0,46.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: CE4RSF-13>APRS,TCPIP*,qAC,T2ROMANIA:T#629,014,298,000,000,000,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: HB9BO-B>APJI40,TCPIP*,qAC,HB9BO-GS:<IGATE,MSG_CNT=0,LOC_CNT=1
#  Format is not supported: '<' station capabilities
# Error parsing line: ER-OK0AE>RXTLM-1,TCPIP,qAR,OK0AE:T#121,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: BM2OBM-11>OBM2BM,qAS,BV6JR-2:T#035,75,7,69,1897,323,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: CMRV>APRX29,TCPIP*,qAC,FIRST:!0.00/00000.00#W8VFR DigiGate 23 satelites Fix:3D ACoff HDOP=99.99 Alt:0000Ft WiFi AuxOFF
#  invalid format
# Error parsing line: VA7RCV-15>APZMDM,WIDE1-1,WIDE2-2,qAO,VA7RCV-10:T#250,3.599,14.630,4,56.934,,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: YO5ER-10>APDW15,TCPIP*,qAC,T2ROMANIA:T#20,126.6,96.5,000,000,000,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: K2MST-1>APJI43,TCPIP*,qAC,K2MST-12:<IGATE,MSG_CNT=64,LOC_CNT=25
#  Format is not supported: '<' station capabilities
# Error parsing line: KB9WGA-2>APRS,KD9VQI-10*,WIDE1*,KE8OOD-10*,WIDE2*,qAR,KJ4KFJ:$GPRMC,14,A,4458.2127,N,08720.8152,W,0.000,0.0,120,2.2, W * 0
#  Format is not supported: '$' raw gps
# Error parsing line: IR3AI-10>APMI06,TCPIP*,qAC,T2AUSTRIA:T#144,184,000,000,100,000,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: F5BLD>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F5BLD-DP!4847.42N/00751.12ErRNG0034 IPSC2-FRANCE 3 MMDVM 433.4500 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZIC>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZIC-DP!4500.18N/00550.03ErRNG0034 IPSC2-FRANCE 3 Hytera 430.0375@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZKT>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZKT-DP!4832.53N/00737.44ErRNG0034 IPSC2-FRANCE 3 Motorola 430.2875@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZKX>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZKX-DP!4926.02N/00248.45ErRNG0034 IPSC2-FRANCE 3 MMDVM 430.4750@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZJL>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZJL-DP!4437.90N/00458.45ErRNG0034 IPSC2-FRANCE 3 MMDVM 439.4000@-7.6 MHz
#  Format is not supported: ')' item report
# Error parsing line: F4ACU>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F4ACU-DP!4717.40N/00048.00ErRNG0034 IPSC2-FRANCE 3 MMDVM 439.6875@-9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZLJ>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZLJ-DP!4459.12N/00016.36WrRNG0034 IPSC2-FRANCE 3 MMDVM 430.2125 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZJQ>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZJQ-DP!4520.20N/00554.12ErRNG0034 IPSC2-FRANCE 3 MMDVM 430.5625@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZJJ>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZJJ-DP!4520.94N/00535.63ErRNG0034 IPSC2-FRANCE 3 MMDVM 430.0875@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZJH>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZJH-DP!4544.45N/00451.42ErRNG0034 IPSC2-FRANCE 3 MMDVM 439.5625@-7.6 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZYC>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZYC-DP!4454.90N/00536.66ErRNG0034 IPSC2-FRANCE 3 MMDVM 430.1125@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F5ZJH>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F5ZJH-DP!4716.72N/00128.87WrRNG0034 IPSC2-FRANCE 3 MMDVM 430.4250@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: ON7UGO>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)ON7UGO-DP!5034.54N/00443.02ErRNG0034 IPSC2-FRANCE 3 MMDVM 438.6000@-6.0 MHz
#  Format is not supported: ')' item report
# Error parsing line: F4GRL>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F4GRL-DP!4325.33N/00112.07ErRNG0034 IPSC2-FRANCE 3 MMDVM 438.4875@-7.6 MHz
#  Format is not supported: ')' item report
# Error parsing line: F5ZAV>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F5ZAV-DP!4828.78N/00728.45ErRNG0034 IPSC2-FRANCE 3 MMDVM 430.2625@+9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: ON0HSB>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)ON0HSB-DP!5034.45N/00443.81ErRNG0034 IPSC2-FRANCE 3 MMDVM 438.2125@-7.6 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1ZHA>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F1ZHA-DP!4550.49N/00116.63ErRNG0034 IPSC2-FRANCE 3 MMDVM 439.9500@-9.4 MHz
#  Format is not supported: ')' item report
# Error parsing line: F1RMB>APZDMR,QTH*,TCPIP*,qAU,T2STRAS:)F
00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: JP1YLW-I>APIRP2,TCPIP*,qAC,JP1YLW-IS:<IGATE,MSG_CNT=0,LOC_CNT=1
#  Format is not supported: '<' station capabilities
# Error parsing line: KD0ETL-9>S8TV0Q,WA0SDO-10,WIDE1*,WIDE2-1,qAS,KA0GFC-1: <<UI>>:
#  format is not supported
# Error parsing line: EL-DB0TGO>RXTLM-1,TCPIP,qAR,DB0TGO:T#534,0.00,0.00,0,0,0.0,00000000,RemoteLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-DB0TGO>RXTLM-1,TCPIP,qAR,DB0TGO:T#535,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: ER-IW6OCM>RXTLM-1,TCPIP,qAR,IW6OCM:T#066,0.00,0.07,0,8,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: SR8SDI>APRX29,TCPIP*,qAC,T2WARSPL:T#131,30.2,1.1,149.0,6.0,4.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: GB7MNK-1>FBB,qAO,MB7NLB:GB7MNK-1 BPQ node (MNKNOD)
#  format is not supported
# Error parsing line: SR8SDI-2>APRX29,TCPIP*,qAS,SR8SDI:T#131,0.0,5.6,0.0,0.0,25.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-PY2IKE>RXTLM-1,TCPIP,qAR,PY2IKE:T#427,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: HB9BO-C>APJI40,TCPIP*,qAC,HB9BO-GS:<IGATE,MSG_CNT=0,LOC_CNT=0
#  Format is not supported: '<' station capabilities
# Error parsing line: SR4BPA>APRX29,TCPIP*,qAC,T2POLC:T#131,2.7,0.4,10.0,0.0,1.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: ER-SR9E>RXTLM-1,TCPIP,qAR,SR9E:T#479,0.00,0.01,0,1,0.0,01000000,RepeaterLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: KJ4ERJ-12>APWA01,TCPIP*,qAC,T2UK:T#896,000,084,285,001,001,00010000
#  Format is not supported: 'T' telemetry report
# Error parsing line: SR5SAN>APRX29,TCPIP*,qAC,T2POLC:T#131,29.3,4.0,132.0,5.0,15.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: SR4LG>APRX29,TCPIP*,qAC,T2POLC:T#131,9.4,0.0,36.0,0.0,0.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: SR5SAN-2>APRX29,TCPIP*,qAS,SR5SAN:T#131,5.9,1.2,22.0,1.0,5.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: W5AUU-2>APTT4,qAR,KA5MGL:T#030,135,067,000,000,113,00000011
#  Format is not supported: 'T' telemetry report
# Error parsing line: KB8ZXE-1>APRX29,TCPIP*,qAC,T2ROMANIA:T#895,14.2,0.0,69.0,0.0,0.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-PY3SAU>RXTLM-1,TCPIP,qAR,PY3SAU:T#124,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: XE2KI-10>APDW17,TCPIP*,qAC,APRSMX-1:T#514,1840,27172,72,635,67,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-F4AGZ>RXTLM-1,TCPIP,qAR,F4AGZ:T#001,0.00,0.01,0,3,0.0,01000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: YM2KAP>APMI03,WIDE2-2,qAO,TA2BI-10:T#060,167,072,041,082,079,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: K5RKN-B>APJI43,TCPIP*,qAC,K5RKN-GS:<IGATE,MSG_CNT=0,LOC_CNT=0
#  Format is not supported: '<' station capabilities
# Error parsing line: K5RKN-C>APJI43,TCPIP*,qAC,K5RKN-GS:<IGATE,MSG_CNT=0,LOC_CNT=1
#  Format is not supported: '<' station capabilities
# Error parsing line: DJ9FK-9>UQ4PW1,DB0ABB*,DB0WIZ,WIDE1*,DB0OI*,WIDE2*,qAR,DL8MKG-12:`B$l ?>/]"6%}
#  invalid data format
# Error parsing line: HS6KLJ-3>AESPG4,TCPIP*,qAC,T2CS:T#001,0,0,0,54,0.02,00000000,@ 19 41 8 13 11 2023
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-K9OY>RXTLM-1,TCPIP,qAR,K9OY:T#039,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: SRT-1>AESPG4,TCPIP*,qAC,T2SAPPORO:T#2038,0,0,0,53,2,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: YO3FBD-11>APDW15,TCPIP*,qAC,T2ROMANIA:T#101,111.5,106.7,113.9,000,000,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: YT3NIV-2>APDW14,WIDE2-1,qAR,YT3NSB:<IGATE,MSG_CNT=0,PKT_CNT=0,DIR_CNT=3,LOC_CNT=11,RF_CNT=17,UPL_CNT=5526,DNL_CNT=8034
#  Format is not supported: '<' station capabilities
# Error parsing line: WT4R-1>APRX29,TCPIP*,qAC,T2CAEAST:T#313,1.2,1.5,5.0,0.0,6.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: KA9RES>APWW11,TCPIP*,qAC,T2USANW:T#891,100,048,002,128,000,10000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: YO3KXL-10>APDW16,TCPIP*,qAC,T2ROMANIA:T#57,108.9,111.0,118.2,000,000,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: KK7DFL-C>APJI43,TCPIP*,qAC,KK7DFL-GS:<IGATE,MSG_CNT=0,LOC_CNT=0
#  Format is not supported: '<' station capabilities
# Error parsing line: ER-LU3DJ>RXTLM-1,TCPIP,qAR,LU3DJ:T#042,0.00,0.00,0,0,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: XE1DGC-10>APDI22,TCPIP*,qAC,T2MEXICO:<IGATE,MSG_CNT=0,LOC_CNT=10,DIR_CNT=4,RF_CNT=21,RFPORT_ID=all
#  Format is not supported: '<' station capabilities
# Error parsing line: CMRV>APRX29,TCPIP*,qAC,FIRST:!0.00/00000.00#W8VFR DigiGate 3D 23sats ACoff GPS-No fix 0000FT
#  invalid format
# Error parsing line: YO9ABK-10>APDW17,TCPIP*,qAC,T2ROMANIA:T#153,104.9,000,000,000,000,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: ER-IR3EB>RXTLM-1,TCPIP,qAR,IR3EB:T#889,0.00,0.01,0,1,0.0,00000000,RepeaterLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-DO7BM>RXTLM-1,TCPIP,qAR,DO7BM:T#286,0.00,0.00,0,0,0.0,00000000,FRN_Logic
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-DO7BM>RXTLM-1,TCPIP,qAR,DO7BM:T#287,0.00,0.00,0,1,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: CQ0DCS-B>APJI43,TCPIP*,qAC,CQ0DCS-GS:<IGATE,MSG_CNT=0,LOC_CNT=1
#  Format is not supported: '<' station capabilities
# Error parsing line: WA7DRE-A>APJI43,TCPIP*,qAC,WA7DRE-GS:<IGATE,MSG_CNT=0,LOC_CNT=1
#  Format is not supported: '<' station capabilities
# Error parsing line: WA7DRE-B>APJI43,TCPIP*,qAC,WA7DRE-GS:<IGATE,MSG_CNT=0,LOC_CNT=0
#  Format is not supported: '<' station capabilities
# Error parsing line: JI6FPP-10>APU25N,TCPIP*,qAC,T2HAKATA:<IGATE,MSG_CNT=15,LOC_CNT=5
#  Format is not supported: '<' station capabilities
# Error parsing line: W9TTN-B>APJI43,TCPIP*,qAC,W9TTN-GS:<IGATE,MSG_CNT=0,LOC_CNT=1
#  Format is not supported: '<' station capabilities
# Error parsing line: EL-GB7RM>RXTLM-1,TCPIP,qAR,GB7RM:T#099,5666348.00,0.01,0,1,0.0,00000000,TetraLogic
#  Format is not supported: 'T' telemetry report
# Error parsing line: HB9AM-10>APRX29,TCPIP*,qAC,T2SWISS1:T#090,13.1,1.2,60.0,0.0,6.0,00000000
#  Format is not supported: 'T' telemetry report
# Error parsing line: EL-PY4EI>RXTLM-1,TCPIP,qAR,PY4EI:T#336,0.00,0.00,0,1,0.0,00000000,SimplexLogic
#  Format is not supported: 'T' telemetry report
# ---------------------------------------------------------------------------
# UnknownFormat                             Traceback (most recent call last)
# c:\Users\malon\Desktop\Tfg\APRSint\app\src\parse.ipynb Cell 4 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/malon/Desktop/Tfg/APRSint/app/src/parse.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> try:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/malon/Desktop/Tfg/APRSint/app/src/parse.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     packets.append(aprs.parse(line[:-1]))
#       <a href='vscode-notebook-cell:/c%3A/Users/malon/Desktop/Tfg/APRSint/app/src/parse.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> except Exception as e:
#
# File c:\Users\malon\miniconda3\envs\tfg_env\Lib\site-packages\aprslib\parsing\__init__.py:134, in parse(packet)
#     133 try:
# --> 134     _try_toparse_body(packet_type, body, parsed)
#     136 # capture ParseErrors and attach the packet
#
# File c:\Users\malon\miniconda3\envs\tfg_env\Lib\site-packages\aprslib\parsing\__init__.py:162, in _try_toparse_body(packet_type, body, parsed)
#     161 if packet_type in unsupported_formats:
# --> 162     raise UnknownFormat("Format is not supported: '{}' {}".format(packet_type, unsupported_formats[packet_type]))
#     164 # 3rd party traffic
#
# UnknownFormat: Format is not supported: '<' station capabilities
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\malon\Desktop\Tfg\APRSint\app\src\parse.ipynb Cell 4 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/malon/Desktop/Tfg/APRSint/app/src/parse.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     packets.append(aprs.parse(line[:-1]))
#       <a href='vscode-notebook-cell:/c%3A/Users/malon/Desktop/Tfg/APRSint/app/src/parse.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> except Exception as e:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/malon/Desktop/Tfg/APRSint/app/src/parse.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     print('Error parsing line: ' + line.decode('utf-8') + " " + str(e))
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 107: invalid start byte

# %%
packets
# Out:
# [{'raw': 'BR4DS-S>APDG01,TCPIP*,qAC,BR4DS-GS:;BR4DS  B *131857z3122.05ND12115.18EaRNG0001/A=000010 440 Voice 439.98750MHz -8.0000MHz\'WINLINK>APWL2K,TCPIP*,qAS,WLNK-1:;KX1EOC-10*130657z4123.  NW07327.  Wa145.030MHz Winlink Packet Gateway\'EA4CZ-10>APLG01,TCPIP*
,TCPIP*,qAC,T2FINLAND:!3008.43N/08149.81WI OP:Scott - KK4ECR RFinder: https://hihello.me/hi/kk4ecr\'ER-DB0EWB>RXTLM-1,TCPIP,qAR,DB0EWB::ER-DB0EWB:UNIT.RX Erlang,TX Erlang,RXcount/10m,TXcount/10m,none1,STxxxxxx,logic\'DO3MHA-13>AP51WX,TCPIP*,qAC,T2ROMANIA:!4848.91N/01133.71E_225/015g024t054r000p050h99b09984Pressure=QNH; Sys-Voltage:  24.4V \'N8GD-1>APU25N,TCPIP*,qAC,T2ALBERTA:<IGATE,MSG_CNT=156,LOC_CNT=15\'AIS>APDW16,qAO,KD9NYE-10:{DA!AIVDM,1,1,,A,15NaeH?P00qV5c2GC;O>4?vnR6CT,0*22\'ER-DB0EWB>RXTLM-1,TCPIP,qAR,DB0EWB:T#326,0.00,1.00,0,1,0.0,01000000,RepeaterLogic\'KE0PVI>APU25N,TCPIP*,qAC,T2MCI:=3831.09N/09440.29W_Weather for Louisburg Kansas {UIV32N}\'YM4KDI>BEACON,WIDE2-2,qAR,TB4DSC-10:www.FARAD.org.tr - Fethiye Amator Radyo Dernegi\'K0WXC-1>APRS,TCPIP*,qAC,T2FINLAND:@131855z4008.96N/09237.79W_c062s007g014t065r000P000h27b10317\'OK1SDR-1>APNL51,TCPIP*,qAI,OK1SDR-1,T2CZECH,T2HUB1,THIRD,FIFTH:!4956.10N/01233.39E`\\xc2\\xae RASTR RAdioSonde TRacker powered by dxlAPRS.\'2E0KFG-B>APDG02,TCPIP*,qAC,2E0KFG-BS:!5151.96ND00055.76E&RNG0001/A=000010 440 Voice 439.40000MHz -9.0000MHz\'PE0FK-S>APDG01,TCPIP*,qAC,PE0FK-GS:;PE0FK  B *131857z5120.50ND00553.59EaRNG0001/A=000115 440 Voice 438.60000MHz -7.6000MHz\'NZ8D-S>APDG01,TCPIP*,qAC,NZ8D-GS:;NZ8D   B *131857z4054.05ND08051.41WaRNG0001/A=000010 440 Voice 434.88750MHz +0.0000MHz\'KN6EWD-N>APDG03,TCPIP*,qAC,KN6EWD-NS:!3335.15ND11713.51W&/A=000000440 MMDVM Voice 446.17500MHz +0.0000MHz, KN6EWD_Pi-Star_ND\'CT1ENI-8>APRS,CT1FGS-1*,WIDE2-1,qAR,CQ0PSI-3:!3836.95N/00910.53Wy Digi/Node:CT1ENI-8  BBS:CT1ENI-5  Band:VHF  Web:http://ct1eni.pt\'SM7DSE-3>APMI06,TCPIP*,qAC,T2LEIPZIG:@131857z5527.11N/01356.11E#  Ystad Digi W2\'DK4KM-1>APET51,TCPIP*,qAC,DK4KM-10:!5 ...
#   'from': 'BR4DS-S',
#   'to': 'APDG01',
#   'path': ['TCPIP*', 'qAC', 'BR4DS-GS'],
#   'via': 'BR4DS-GS',
#   'object_name': 'BR4DS  B ',
#   'alive': True,
#   'raw_timestamp': '131857z',
#   'timestamp': 1699901820,
#   'format': 'object',
#   'posambiguity': 0,
#   'symbol': 'a',
#   'symbol_table': 'D',
#   'latitude': 31.367589743589743,
#   'longitude': 121.25300732600732,
#   'rng': 1.609344,
#   'altitude': 3.048,
#   'daodatumbyte': 'W',
#   'comment': '440 Voice 439.98750MHz -8.0000MHz\'WINLINK>APWL2K,TCPIP*,qAS,WLNK-1:;KX1EOC-10*130657z4123.  NW07327.  Wa145.030MHz Winlink Packet Gateway\'EA4CZ-10>APLG01,TCPIP*,qAC,T2NORWAY:=4024.48NL00403.36W&LoRa iGATE & Digi, by Daniboy\'DO1HNP-9>UR1XV9,WIDE1-1,WIDE2-2,qAO,DF0TWN-11:`})Qms>>/`"4&}_%\'K5PTW-9>SSPT4S,WIDE1-1,WIDE2-1,qAR,K5PRK-11:`|Fxl"w>/`"5t}_(\'E25MTT-2>AESPG4,TCPIP*,qAC,T2THAI:@131857z1402.47N/10034.94E_000/000g000t092r...p...P...h55b10130L000 Indy Igate : [[Cloudy]] SUN T=33\\xc2\\xb0 H=55%   P=1013\'KG7UL-9>TRQRUX,WIDE1-1,WIDE2-1,qAR,W7VW-1:`1I l!,j/"Ab}144.390MHz 4.20V  73.5F_X\'VE7PRT-1>APRX29,WIDE2-2,TCPIP*,qAS,VE7PRT-2:!4856.50N/12533.07W_017/000g000t045r000P004h95b10190\'KN4ITN-R>APDG03,TCPIP*,qAC,KN4ITN-RS:!2533.90ND08024.31W&/A=0000002m MMDVM Voice 145.52500MHz -0.6000MHz, KN4ITN_Pi-Star_RPT\'JG6YCL-2>SSTXQ9,WIDE1-1,qAO,JG6YCL-15:\':=xl \\x1c#/]144.64MHz 9600bps Munakata="LU9FW-5>APRS,TCPIP*,qAC,T2CZECH:@131856z3317.79S/06111.16W_090/005g011t070r000p000P000b10036h67eMB39\'KD6PPM>BEACON,AC6EE-3,WIDE2*,qAR,KJ6HUP:!3508.63N/11838.79W`\'V51RS>AP7ATA,TCPIP*,qAC,T2ERFURT:;Gamsberg *111111z2316.53S/01616.10ErGamsberg Link connect to Windhoek, 430.350MHz, T100 + 145.150MHz, T88.5 connect to Swakopmund\'E24ZVH-5>APDR16,TCPIP*,qAC,T2FINLAND:=1852.2 N/09908.4 EP145.400MHz/A=001167 https://aprsdroid.org/\'KJ4PGD-1>APMI06,TCPIP*,qAS,KJ4PGD:@131857z3737.84NI07848.84W&PHG7630 W1, VAn-N James River State Park\'KL5FX-N>APDG03,TCPIP*,qAC,KL5FX-NS:!6107.53ND14950.78W&/A=000000440 MMDVM Voice 434.60000MHz +0.0000MHz, KL5FX_Pi-Star_ND\'E20FMC-1>AESPG4,TCPIP*,qAC,T2FUKUOKA:T#073,0,0,0,40,3.32,00000000,@ 18 57 25 13 11 2023\'BG2VZP-3>APOT21,RELAY-1*,BG2WHR-3*,WIDE1*,qAR,BG2VIA:!3911.02N/12203.72E# 12.7V  29C APRS DIGIRepeater Of Dengshahe144.640\'VE3NOZ-1>APWW11,TCPIP*,qAC,T2STRAS:@185727h4352.32N/08142.95W-APRS-IS for Win32\'OE7SAE-2>APNL51,TCPIP*,qAI,OE7SAE-2,T2AUSTRIA,T2HUB2,SIXTH,FIFTH:!4720.08N/01111.04E`iGate OE7SAE-2 Radiosonde-RX@Raspi3\'SR5NWA>APRX28,W